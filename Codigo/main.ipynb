# %% [markdown]
# ## MAIN

# %%
import pandas as pd
import numpy as np

ev4 = pd.read_csv('../Datasets/evaluacion4_produccion.csv')
ev4.head(10)
# Out:
#                    category         subtype market_tier condition  \
# 0      PC Components (Core)    ssd_internal  Mainstream       New
# 1      PC Components (Core)    ssd_internal  Mainstream       New
# 2  Office, Printing & Power       toner_ink  Mainstream       New
# 3  Office, Printing & Power       toner_ink  Mainstream       New
# 4     Audio & Media Systems      headphones  Mainstream       New
# 5  Office, Printing & Power         battery  Mainstream       New
# 6     Audio & Media Systems         earbuds  Mainstream       New
# 7            Mobile Devices      smartwatch  Mainstream       New
# 8               Accessories  remote_control  Mainstream       New
# 9  Office, Printing & Power       toner_ink  Mainstream       New
#
#    is_premium_brand tech_generation          brand  confidence printer_tech  \
# 0             False     Current-Gen            OWC        0.95          NaN
# 1              True     Current-Gen            OWC        0.95          NaN
# 2              True     Current-Gen             HP        0.95       Inkjet
# 3             False     Current-Gen             HP        0.95       Inkjet
# 4             False     Current-Gen           Sony        0.95          NaN
# 5             False     Current-Gen       Duracell        0.95          NaN
# 6              True     Current-Gen          Apple        0.95          NaN
# 7              True     Current-Gen          Apple        0.95          NaN
# 8             False     Current-Gen           Roku        0.90          NaN
# 9             False     Current-Gen  Amazon Basics        0.90          NaN
#
#   is_color  ... buy_box_availability sustainability_tags  has_coupon  \
# 0      NaN  ...                    1                   0           0
# 1      NaN  ...                    1                   0           0
# 2    False  ...                    0                   1           0
# 3     True  ...                    0                   0           0
# 4     True  ...                    0                   0           0
# 5      NaN  ...                    1                   0           0
# 6      NaN  ...                    0                   0           0
# 7      NaN  ...                    0                   0           0
# 8      NaN  ...                    0                   1           0
# 9      NaN  ...                    1                   0           0
#
#    discount_percentage log_original_price  log_purchased_last_month  \
# 0                 0.00           5.484755                  0.000000
# 1                 0.00           3.783962                  0.000000
# 2                 0.00           3.607941                 10.819798
# 3                 0.00           3.804215                 10.819798
# 4                 0.00           2.355178                  9.210440
# 5                 0.14           3.130700                 11.289794
# 6                 0.00           2.839078                  9.210440
# 7                 0.00           4.991385                  9.210440
# 8                 0.00           3.541249                  9.210440
# 9                 0.00           2.889260                 11.512935
#
#   log_total_reviews            brand_subtype  \
# 0          5.883322         OWC_ssd_internal
# 1          5.624018         OWC_ssd_internal
# 2         11.523598             HP_toner_ink
# 3         10.986868             HP_toner_ink
# 4         11.598433          Sony_headphones
# 5         11.739304         Duracell_battery
# 6          9.621655            Apple_earbuds
# 7          9.460398         Apple_smartwatch
# 8          7.554859      Roku_remote_control
# 9         11.396010  Amazon Basics_toner_ink
#
#                                            image_url  \
# 0  https://m.media-amazon.com/images/I/51vvx1JymA...
# 1  https://m.media-amazon.com/images/I/41d4RtiB8E...
# 2  https://m.media-amazon.com/images/I/71y57XPIia...
# 3  https://m.media-amazon.com/images/I/51eBahpKda...
# 4  https://m.media-amazon.com/images/I/41CiQ7hR31...
# 5  https://m.media-amazon.com/images/I/71F1yxjGeY...
# 6  https://m.media-amazon.com/images/I/513OSdW4el...
# 7  https://m.media-amazon.com/images/I/61umEhyV-U...
# 8  https://m.media-amazon.com/images/I/71mye7IQ5j...
# 9  https://m.media-amazon.com/images/I/61cefAp7H5...
#
#                                          product_url
# 0  /sspa/click?ie=UTF8&spc=MTo4NzEzNDY2NTQ5NDYxND...
# 1  /sspa/click?ie=UTF8&spc=MTo4NzEzNDY2NTQ5NDYxND...
# 2  /HP-Cartridge-Black-3YM57AN-Tri-Color/dp/B0841...
# 3  /HP-Cartridges-Black-Tri-Color-3YP29AN/dp/B084...
# 4  /Sony-MDRZX110-BLK-Stereo-Headphones/dp/B00NJ2...
# 5                                                NaN
# 6  /Apple-EarPods-Headphones-Built-Control/dp/B0D...
# 7  /Apple-Smartwatch-Starlight-Aluminum-Detection...
# 8  /Roku-Streaming-Stick-HD-2025/dp/B0DXXYS4BJ/re...
# 9  /AmazonBasics-Thermal-Laminating-Plastic-Lamin...
#
# [10 rows x 114 columns]

# %%
ev4.rename(columns={'image_url':'product_image_url'}, inplace=True)
ev4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6322 entries, 0 to 6321
# Columns: 114 entries, category to product_url
# dtypes: bool(2), float64(31), int64(3), object(78)
# memory usage: 5.4+ MB

# %%
ev4.product_image_url
# Out:
# 0       https://m.media-amazon.com/images/I/51vvx1JymA...
# 1       https://m.media-amazon.com/images/I/41d4RtiB8E...
# 2       https://m.media-amazon.com/images/I/71y57XPIia...
# 3       https://m.media-amazon.com/images/I/51eBahpKda...
# 4       https://m.media-amazon.com/images/I/41CiQ7hR31...
#                               ...
# 6317    https://m.media-amazon.com/images/I/71RLbyxkUp...
# 6318    https://m.media-amazon.com/images/I/81bLVfMTrN...
# 6319    https://m.media-amazon.com/images/I/81U+SuxDL9...
# 6320    https://m.media-amazon.com/images/I/71IrtnjZD2...
# 6321    https://m.media-amazon.com/images/I/71wTn+zoSr...
# Name: product_image_url, Length: 6322, dtype: object

# %%
ev4.to_csv('../Datasets/evaluacion4_produccion.csv', index=False)

# %%
dashb = pd.read_csv("data_dashboard.csv")
dashb.head()
# Out:
#                    category       subtype market_tier condition  \
# 0      PC Components (Core)  ssd_internal  Mainstream       New
# 1      PC Components (Core)  ssd_internal  Mainstream       New
# 2  Office, Printing & Power     toner_ink  Mainstream       New
# 3  Office, Printing & Power     toner_ink  Mainstream       New
# 4     Audio & Media Systems    headphones  Mainstream       New
#
#    is_premium_brand tech_generation brand  confidence printer_tech is_color  \
# 0             False     Current-Gen   OWC        0.95          NaN      NaN
# 1              True     Current-Gen   OWC        0.95          NaN      NaN
# 2              True     Current-Gen    HP        0.95       Inkjet    False
# 3             False     Current-Gen    HP        0.95       Inkjet     True
# 4             False     Current-Gen  Sony        0.95          NaN     True
#
#    ... is_best_seller is_sponsored  buy_box_availability  sustainability_tags  \
# 0  ...       No Badge    Sponsored                     1                    0
# 1  ...       No Badge    Sponsored                     1                    0
# 2  ...    Best Seller      Organic                     0                    1
# 3  ...       No Badge      Organic                     0                    0
# 4  ...    Best Seller      Organic                     0                    0
#
#   has_coupon  discount_percentage log_original_price log_purchased_last_month  \
# 0          0                  0.0           5.484755                 0.000000
# 1          0                  0.0           3.783962                 0.000000
# 2          0                  0.0           3.607941                10.819798
# 3          0                  0.0           3.804215                10.819798
# 4          0                  0.0           2.355178                 9.210440
#
#    log_total_reviews                                  product_image_url
# 0           5.883322  https://m.media-amazon.com/images/I/51vvx1JymA...
# 1           5.624018  https://m.media-amazon.com/images/I/41d4RtiB8E...
# 2          11.523598  https://m.media-amazon.com/images/I/71y57XPIia...
# 3          10.986868  https://m.media-amazon.com/images/I/51eBahpKda...
# 4          11.598433  https://m.media-amazon.com/images/I/41CiQ7hR31...
#
# [5 rows x 112 columns]

# %%
def info_df(df):
    return pd.DataFrame({
    'Columna': df.columns,
    'No Nulos': df.notnull().sum().values,
    'Nulos': df.isnull().sum().values,
    'Tipo Python': df.dtypes.values,
    'Núm. valores': [len(df[col].unique()) for col in df.columns]
     })
info = info_df(dashb)
info
# Out:
#                       Columna  No Nulos  Nulos Tipo Python  Núm. valores
# 0                    category      6445      0      object            10
# 1                     subtype      6445      0      object            98
# 2                 market_tier      6445      0      object             4
# 3                   condition      6445      0      object             2
# 4            is_premium_brand      6445      0        bool             2
# ..                        ...       ...    ...         ...           ...
# 110       discount_percentage      6445      0     float64            71
# 111        log_original_price      6445      0     float64          2656
# 112  log_purchased_last_month      6445      0     float64            30
# 113         log_total_reviews      6445      0     float64          3509
# 114         product_image_url      6445      0      object          6343
#
# [115 rows x 5 columns]

# %%
cols_dashb_not_ev4 = set(dashb.columns) - set(ev4.columns)
print(cols_dashb_not_ev4)
# Out:
# {'original_title', 'product_image_url'}

# %%
df_clean['total_reviews'] = np.exp(df_clean['log_total_reviews'])

# %%
df_clean[(df_clean.category == 'Office, Printing & Power') & (df_clean.subtype == 'printer') & (df_clean.brand == 'Canon' )]

# %%
df_clean = pd.read_csv('../Datasets/amazon_products_sales_data_cleaned.csv')
df_clean.head(1)
# Out:
#                                        product_title  product_rating  \
# 0  BOYA BOYALINK 2 Wireless Lavalier Microphone f...             4.6
#
#    total_reviews  purchased_last_month  discounted_price  original_price  \
# 0          375.0                 300.0             89.68           159.0
#
#   is_best_seller is_sponsored             has_coupon buy_box_availability  \
# 0       No Badge    Sponsored  Save 15%  with coupon          Add to cart
#
#   delivery_date sustainability_tags  \
# 0    2025-09-01       Carbon impact
#
#                                    product_image_url  \
# 0  https://m.media-amazon.com/images/I/71pAqiVEs3...
#
#                                     product_page_url    data_collected_at  \
# 0  https://www.amazon.com/sspa/click?ie=UTF8&spc=...  2025-08-21 11:14:29
#
#   product_category  discount_percentage
# 0           Phones                 43.6

# %%
df_uncleaned.sustainability_badges.value_counts()
# Out:
# sustainability_badges
# Small Business                    1341
# Carbon impact                      769
# Works with Alexa                   425
# Energy efficiency                  262
# Alexa Built-in                     184
# Manufacturing practices            148
# Energy efficiency +3 more          121
# Energy efficiency +1 more           93
# Forestry practices                  18
# Safer chemicals +2 more             18
# Recycled materials                   7
# Recycled materials +2 more           7
# Safer chemicals +1 more              6
# Recycled materials +3 more           4
# Made in Italy                        4
# 1 sustainability certification       1
# Name: count, dtype: int64

# %%
df_clean.is_best_seller.value_counts()
# Out:
# is_best_seller
# No Badge             40814
# Amazon's               744
# Limited time deal      409
# Best Seller            275
# Save 30%               125
# Ends in                 97
# Save 10%                61
# Save 18%                57
# Save 17%                51
# Save 12%                26
# Save 9%                 14
# Save 77%                 2
# Name: count, dtype: int64

# %% [markdown]
# ### HAS_COUPON : 0/1
# ### AÑADIR DISCOUNT_COUPON: Integer: coupon value (%)
# ### DELIVERY DATE (ES UTIL????? QUITAR)
