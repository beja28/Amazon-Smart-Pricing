# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import Image, HTML

# %%
ev1 = pd.read_csv('../../Datasets/amazon_final.csv')
ev1.head(1)
# Out:
#                                        product_title  product_rating  \
# 0  OWC 2.0TB Aura Pro X2 (GEN 4) SSD Complete Upg...             4.4
#
#    total_reviews  purchased_last_month  original_price  is_sponsored  \
# 0          358.0                     0          239.99             1
#
#       coupon  buy_box_availability  sustainability_tags  \
# 0  No Coupon                     1                    0
#
#                                    product_image_url  ...  \
# 0  https://m.media-amazon.com/images/I/51vvx1JymA...  ...
#
#    badge_limited_time_deal  badge_no_badge  badge_save_xpct  product_category  \
# 0                        0               1                0     PC Components
#
#    log_purchased_last_month  log_original_price  segment_Alta/Premium  \
# 0                       0.0            5.484755                     0
#
#    segment_Baja segment_Media  log_total_reviews
# 0             0             1           5.883322
#
# [1 rows x 25 columns]

# %% [markdown]
# - DROP purchased_last_month
# - DROP total_reviews
# - DROP original_price
# - DROP coupon
# - DROP title
# - DROP product_img

# %%
ev1.drop(columns=['product_title', 'total_reviews', 'purchased_last_month', 'original_price', 'coupon', 'product_image_url'], inplace=True)

# %%
ev1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7717 entries, 0 to 7716
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   product_rating            7717 non-null   float64
#  1   is_sponsored              7717 non-null   int64
#  2   buy_box_availability      7717 non-null   int64
#  3   sustainability_tags       7717 non-null   int64
#  4   has_coupon                7717 non-null   int64
#  5   discount_percentage       7717 non-null   float64
#  6   badge_amazons             7717 non-null   int64
#  7   badge_best_seller         7717 non-null   int64
#  8   badge_ends_in             7717 non-null   int64
#  9   badge_limited_time_deal   7717 non-null   int64
#  10  badge_no_badge            7717 non-null   int64
#  11  badge_save_xpct           7717 non-null   int64
#  12  product_category          7717 non-null   object
#  13  log_purchased_last_month  7717 non-null   float64
# ...

# %%
ev1.to_csv('../../Datasets/evaluacion1.csv', index=False)

# %% [markdown]
# ## ¿OHE CATEGORY?
